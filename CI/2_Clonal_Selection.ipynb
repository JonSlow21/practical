# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Objective function (we want to minimize this)
def objective_function(x):
    return x[0]**2 + x[1]**2  # Simple paraboloid

# Generate a random antibody (solution)
def random_antibody(bounds):
    return np.random.uniform(bounds[0], bounds[1], 2)

# Mutate an antibody (small change)
def mutate(antibody, mutation_rate, bounds):
    mutation = antibody + np.random.normal(0, mutation_rate, size=2)
    return np.clip(mutation, bounds[0], bounds[1])

# Main Clonal Selection Algorithm with theoretical outputs
def clonal_selection(objective_function, bounds, n_population=20, n_generations=50, n_clones=5, mutation_rate=0.1):

    population = [random_antibody(bounds) for _ in range(n_population)]
    history = []

    print("=== Clonal Selection Algorithm Theoretical Output ===\n")

    for gen in range(n_generations):
        fitness = np.array([objective_function(p) for p in population])
        sorted_indices = np.argsort(fitness)
        population = [population[i] for i in sorted_indices]
        best = population[0]
        best_fitness = fitness[sorted_indices[0]]
        avg_fitness = np.mean(fitness)

        # Print theoretical output
        print(f"Generation {gen+1:02d}:")
        print(f"  ▶ Best Antibody: {best}")
        print(f"  ▶ Best Fitness : {best_fitness:.4f}")
        print(f"  ▶ Avg Fitness  : {avg_fitness:.4f}\n")

        history.append(population)

        # Clone and mutate
        new_population = []
        for i in range(n_population):
            for _ in range(n_clones):
                clone = mutate(population[i], mutation_rate, bounds)
                new_population.append(clone)

        new_fitness = np.array([objective_function(p) for p in new_population])
        best_indices = np.argsort(new_fitness)[:n_population]
        population = [new_population[i] for i in best_indices]

    return history

# Animation function
def animate_clonal_selection(history, bounds):
    fig, ax = plt.subplots()
    x = np.linspace(bounds[0], bounds[1], 100)
    y = np.linspace(bounds[0], bounds[1], 100)
    X, Y = np.meshgrid(x, y)
    Z = objective_function([X, Y])
    contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
    scat = ax.scatter([], [], c='red', s=30)

    # Add color bar and labels
    cbar = fig.colorbar(contour, ax=ax)
    cbar.set_label("Objective Function Value")
    ax.set_xlabel("X1")
    ax.set_ylabel("X2")

    def update(frame):
        data = np.array(history[frame])
        scat.set_offsets(data)
        ax.set_title(f"Clonal Selection - Generation {frame + 1}")
        return scat,

    ani = animation.FuncAnimation(fig, update, frames=len(history), interval=300, blit=True)
    plt.show()

# Parameters
bounds = [-5, 5]
history = clonal_selection(objective_function, bounds, n_population=15, n_generations=50, n_clones=5, mutation_rate=0.2)
animate_clonal_selection(history, bounds)
# Out:
# === Clonal Selection Algorithm Theoretical Output ===
#
# Generation 01:
#   ▶ Best Antibody: [1.45065842 0.99941094]
#   ▶ Best Fitness : 3.1032
#   ▶ Avg Fitness  : 20.4318
#
# Generation 02:
#   ▶ Best Antibody: [1.48086646 0.86875444]
#   ▶ Best Fitness : 2.9477
#   ▶ Avg Fitness  : 7.9137
#
# Generation 03:
#   ▶ Best Antibody: [1.18889385 0.72818524]
#   ▶ Best Fitness : 1.9437
#   ▶ Avg Fitness  : 2.6382
#
# Generation 04:
#   ▶ Best Antibody: [0.73821366 0.69956305]
#   ▶ Best Fitness : 1.0343
#   ▶ Avg Fitness  : 1.6185
#
# Generation 05:
#   ▶ Best Antibody: [0.45764736 0.51129755]
#   ▶ Best Fitness : 0.4709
#   ▶ Avg Fitness  : 0.9239
#
# Generation 06:
#   ▶ Best Antibody: [-0.07698549  0.1200563 ]
#   ▶ Best Fitness : 0.0203
#   ▶ Avg Fitness  : 0.4125
#
# Generation 07:
#   ▶ Best Antibody: [-0.03377729  0.04671087]
#   ▶ Best Fitness : 0.0033
#   ▶ Avg Fitness  : 0.0937
#
# Generation 08:
#   ▶ Best Antibody: [ 0.02416803 -0.0099087 ]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0206
#
# Generation 09:
#   ▶ Best Antibody: [ 0.00547547 -0.02568883]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0083
#
# Generation 10:
#   ▶ Best Antibody: [ 0.00950294 -0.02874068]
#   ▶ Best Fitness : 0.0009
#   ▶ Avg Fitness  : 0.0117
#
# Generation 11:
#   ▶ Best Antibody: [-0.01177739  0.02137852]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0154
#
# Generation 12:
#   ▶ Best Antibody: [ 0.01507063 -0.0630403 ]
#   ▶ Best Fitness : 0.0042
#   ▶ Avg Fitness  : 0.0109
#
# Generation 13:
#   ▶ Best Antibody: [0.01343376 0.0157406 ]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0093
#
# Generation 14:
#   ▶ Best Antibody: [-0.02110123  0.01784967]
#   ▶ Best Fitness : 0.0008
#   ▶ Avg Fitness  : 0.0055
#
# Generation 15:
#   ▶ Best Antibody: [-0.02020554 -0.00559838]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0096
#
# Generation 16:
#   ▶ Best Antibody: [-0.02665728  0.00068817]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0099
#
# Generation 17:
#   ▶ Best Antibody: [-0.05368756  0.02159301]
#   ▶ Best Fitness : 0.0033
#   ▶ Avg Fitness  : 0.0112
#
# Generation 18:
#   ▶ Best Antibody: [0.01098276 0.05223272]
#   ▶ Best Fitness : 0.0028
#   ▶ Avg Fitness  : 0.0115
#
# Generation 19:
#   ▶ Best Antibody: [-0.01324556  0.00635903]
#   ▶ Best Fitness : 0.0002
#   ▶ Avg Fitness  : 0.0068
#
# Generation 20:
#   ▶ Best Antibody: [ 0.01521376 -0.01830958]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0101
#
# Generation 21:
#   ▶ Best Antibody: [0.02311992 0.00225406]
#   ▶ Best Fitness : 0.0005
#   ▶ Avg Fitness  : 0.0105
#
# Generation 22:
#   ▶ Best Antibody: [-0.03376802 -0.03519043]
#   ▶ Best Fitness : 0.0024
#   ▶ Avg Fitness  : 0.0102
#
# Generation 23:
#   ▶ Best Antibody: [-0.01532142  0.01230858]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0107
#
# Generation 24:
#   ▶ Best Antibody: [ 0.004166   -0.00782654]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0153
#
# Generation 25:
#   ▶ Best Antibody: [0.03815593 0.00722915]
#   ▶ Best Fitness : 0.0015
#   ▶ Avg Fitness  : 0.0063
#
# Generation 26:
#   ▶ Best Antibody: [ 0.01762583 -0.03246976]
#   ▶ Best Fitness : 0.0014
#   ▶ Avg Fitness  : 0.0075
#
# Generation 27:
#   ▶ Best Antibody: [0.01518492 0.03308153]
#   ▶ Best Fitness : 0.0013
#   ▶ Avg Fitness  : 0.0098
#
# Generation 28:
#   ▶ Best Antibody: [0.01428712 0.0085979 ]
#   ▶ Best Fitness : 0.0003
#   ▶ Avg Fitness  : 0.0080
#
# Generation 29:
#   ▶ Best Antibody: [0.0169574  0.01184513]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0123
#
# Generation 30:
#   ▶ Best Antibody: [0.01721123 0.01358813]
#   ▶ Best Fitness : 0.0005
#   ▶ Avg Fitness  : 0.0071
#
# Generation 31:
#   ▶ Best Antibody: [-0.03816745  0.00315484]
#   ▶ Best Fitness : 0.0015
#   ▶ Avg Fitness  : 0.0184
#
# Generation 32:
#   ▶ Best Antibody: [0.00959395 0.00558733]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0127
#
# Generation 33:
#   ▶ Best Antibody: [-0.00030767 -0.00550695]
#   ▶ Best Fitness : 0.0000
#   ▶ Avg Fitness  : 0.0052
#
# Generation 34:
#   ▶ Best Antibody: [-0.01085601 -0.00283524]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0054
#
# Generation 35:
#   ▶ Best Antibody: [0.00192365 0.04134596]
#   ▶ Best Fitness : 0.0017
#   ▶ Avg Fitness  : 0.0090
#
# Generation 36:
#   ▶ Best Antibody: [0.00554811 0.0101024 ]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0133
#
# Generation 37:
#   ▶ Best Antibody: [0.00158868 0.01540245]
#   ▶ Best Fitness : 0.0002
#   ▶ Avg Fitness  : 0.0101
#
# Generation 38:
#   ▶ Best Antibody: [-0.00891385  0.01093964]
#   ▶ Best Fitness : 0.0002
#   ▶ Avg Fitness  : 0.0085
#
# Generation 39:
#   ▶ Best Antibody: [0.02108599 0.0159366 ]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0061
#
# Generation 40:
#   ▶ Best Antibody: [ 0.01063564 -0.026832  ]
#   ▶ Best Fitness : 0.0008
#   ▶ Avg Fitness  : 0.0134
#
# Generation 41:
#   ▶ Best Antibody: [-0.02962476  0.04994599]
#   ▶ Best Fitness : 0.0034
#   ▶ Avg Fitness  : 0.0112
#
# Generation 42:
#   ▶ Best Antibody: [-0.02404224 -0.04758596]
#   ▶ Best Fitness : 0.0028
#   ▶ Avg Fitness  : 0.0105
#
# Generation 43:
#   ▶ Best Antibody: [ 0.01636082 -0.01773507]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0086
#
# Generation 44:
#   ▶ Best Antibody: [ 0.02781515 -0.00347344]
#   ▶ Best Fitness : 0.0008
#   ▶ Avg Fitness  : 0.0089
#
# Generation 45:
#   ▶ Best Antibody: [-0.05109072  0.01892071]
#   ▶ Best Fitness : 0.0030
#   ▶ Avg Fitness  : 0.0147
#
# Generation 46:
#   ▶ Best Antibody: [0.03359265 0.03552175]
#   ▶ Best Fitness : 0.0024
#   ▶ Avg Fitness  : 0.0178
#
# Generation 47:
#   ▶ Best Antibody: [-0.00362897 -0.02598588]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0080
#
# Generation 48:
#   ▶ Best Antibody: [ 0.02324749 -0.00368729]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0097
#
# Generation 49:
#   ▶ Best Antibody: [-0.0028823 -0.0093055]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0105
#
# Generation 50:
#   ▶ Best Antibody: [-0.0147519   0.00681806]
#   ▶ Best Fitness : 0.0003
#   ▶ Avg Fitness  : 0.0126
